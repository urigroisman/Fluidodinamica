# %%
using Plots

# %%
t = collect(0:100)
P₀ = collect(5:0.02:7);

# %%
T = collect(20:0.4:60)
plot(t, (P₀ .* 1e5) ./ sqrt.(T .+ 273))

# %%
T = collect(20:1.8:200);
plot(t, (P₀ .* 1e5) ./ sqrt.(T .+ 273))

# %%
T = collect(20:2.8:300)
plot(t, (P₀ .* 1e5) ./ sqrt.(T .+ 273))

# %%
T₀ = collect(20:5.8:600)

plot(t, (P₀ .* 1e5) ./ sqrt.(T₀ .+ 273))
